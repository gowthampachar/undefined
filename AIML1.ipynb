# %% [markdown]
# <a href="https://colab.research.google.com/github/gowthampachar/undefined/blob/main/AIML1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def hello():
  print("hello THis is Gowthama... How are you!!")

# %%
hello()
# Out:
# hello THis is Gowthama... How are you!!
